# %%
import pandas as pd

# %%
data = pd.read_excel("ADHD Data.xlsx")
data.head()
# Out:
#     No  Sex Day of birth  Diagnosis Text layout Unnamed: 5 Unnamed: 6  \
# 0  NaN  NaN           NaT       NaN         NaN        NaN        NaN
# 1  NaN  NaN           NaT       NaN           3          1          2
# 2  1.0    M    2002-11-06   control           N          N          N
# 3  2.0    F    1999-05-31      ADHD           N          N          N
# 4  3.0    M    2003-02-13      ADHD           N          N          Y
#
#   Unnamed: 7 Margins  Unnamed: 9  ...    Continuity or  Unnamed: 42  \
# 0        NaN      NaN        NaN  ...  flow connection          NaN
# 1          0        1          2  ...                 0           1
# 2          Y        Y          N  ...                 N           N
# 3          Y        Y          N  ...                 N           Y
# 4          N        Y          N  ...                 N           N
#
#   Unnamed: 43 Unnamed: 44 Shape of  Unnamed: 46 Unnamed: 47  Speed of  \
# ...

# %%
data.shape
# Out:
# (51, 51)

# %%
data = data.drop([0, 1], axis=0)

# %%
data.shape
# Out:
# (49, 51)
